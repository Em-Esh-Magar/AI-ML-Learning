# %% [markdown]
# <a href="https://colab.research.google.com/github/Em-Esh-Magar/AI-ML-Learning/blob/main/Torch/Torch_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
a = torch.tensor(2., requires_grad=True)
b = torch.tensor(5., requires_grad=True)

# %%
c=a*b
d = c*100
d,c
# Out:
# (tensor(1000., grad_fn=<MulBackward0>), tensor(10., grad_fn=<MulBackward0>))

# %%
d.grad_fn

# %%
a = torch.tensor([[7., 9.],
                  [8.,3.]])
b = torch.tensor([[2., 5.],
                  [4.,6.]])

# %%
a.mean()  # total ko mean
# Out:
# tensor(6.7500)

# %%
a.mean(dim=0)    # column ko mean
# Out:
# tensor([7.5000, 6.0000])

# %%
a.mean(dim=1)  # row bata ko mean
# Out:
# tensor([8.0000, 5.5000])

# %%
a*b
# Out:
# tensor([[14., 45.],
#         [32., 18.]])

# %%
a@b    # For matrix multiplication
# Out:
# tensor([[50., 89.],
#         [28., 58.]])

# %%
a.argmax(dim = 0)     # columns ma sab bhanda max value ko index.
# a ko 1st column ma max value 1 index ma xa ani 2nd column ko max value 0 index ma xa.
# Out:
# tensor([1, 0])

# %%
c =  a.flatten()
c
# Out:
# tensor([7., 9., 8., 3.])

# %%
a.argmax()   # argmax ley a ko value lai flatten garxa. ani aaba chai kata max value xa ta tesko index dinxa.
# Out:
# tensor(1)

# %%
a.device
# Out:
# device(type='cuda', index=0)

# %%
a = a.to('cuda')

# %%
# .backwar()
# .zero_grad()
# step()
